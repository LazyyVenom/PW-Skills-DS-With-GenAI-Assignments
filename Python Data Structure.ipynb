# %% [markdown]
# ### Q1

# %% [markdown]
# Reasons to use a queue from python module instead of implementing it using a list.
# 1. Python module based queue is much more efficient in implementing insertion and deletion.
# 2. Python list is based upon array which makes some of the operations to be Big O of n.
# 3. Python list do not strictly restrict us to perform any additional operations on the queue.

# %% [markdown]
# ### Q2

# %% [markdown]
# 1. Parenthesis matching.
# 2. Implementation of plates.
# 3. Implementation of memory stack.
# 4. Stack of books.

# %% [markdown]
# ### Q3

# %% [markdown]
# Sets are really useful data structures. They are not ordered in any way.
#
# Implementations can be whenever we want to only keep distinct values instead of multiple frequencies.
# We can use hash set instead of hashmap so we don't have to keep it frequency just it is already seen.
#
# Sets are also implemented during graph traversal.
#
# Sets can be also useful to sort out only unique requests from a job application.

# %% [markdown]
# ### Q4
